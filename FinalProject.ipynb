# %%
import pandas as pd

# %%
raw_data=pd.read_csv('sample_data/Liver_disease.csv')

# %%
raw_data.head()
# Out:
#    Unnamed: 0  age  gender  total Bilirubin  ...  SGPT  SGOT  Alkphos    y
# 0           0   65  Female              0.7  ...   6.8   3.3     0.90  yes
# 1           1   62    Male             10.9  ...   7.5   3.2     0.74  yes
# 2           2   62    Male              7.3  ...   7.0   3.3     0.89  yes
# 3           3   58    Male              1.0  ...   6.8   3.4     1.00  yes
# 4           4   72    Male              3.9  ...   7.3   2.4     0.40  yes
#
# [5 rows x 12 columns]

# %%
raw_data.describe()
# Out:
#        Unnamed: 0         age  ...        SGOT     Alkphos
# count  583.000000  583.000000  ...  583.000000  579.000000
# mean   291.000000   44.746141  ...    3.141852    0.947064
# std    168.441879   16.189833  ...    0.795519    0.319592
# min      0.000000    4.000000  ...    0.900000    0.300000
# 25%    145.500000   33.000000  ...    2.600000    0.700000
# 50%    291.000000   45.000000  ...    3.100000    0.930000
# 75%    436.500000   58.000000  ...    3.800000    1.100000
# max    582.000000   90.000000  ...    5.500000    2.800000
#
# [8 rows x 10 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 12 columns):
# Unnamed: 0          583 non-null int64
# age                 583 non-null int64
# gender              583 non-null object
# total Bilirubin     583 non-null float64
# direct Bilirubin    583 non-null float64
# total proteins      583 non-null int64
# albumin             583 non-null int64
# A/G ratio           583 non-null int64
# SGPT                583 non-null float64
# SGOT                583 non-null float64
# Alkphos             579 non-null float64
# y                   583 non-null object
# dtypes: float64(5), int64(5), object(2)
# memory usage: 54.8+ KB

# %%
raw_data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
raw_data.describe()
# Out:
#               age  total Bilirubin  ...        SGOT     Alkphos
# count  583.000000       583.000000  ...  583.000000  579.000000
# mean    44.746141         3.298799  ...    3.141852    0.947064
# std     16.189833         6.209522  ...    0.795519    0.319592
# min      4.000000         0.400000  ...    0.900000    0.300000
# 25%     33.000000         0.800000  ...    2.600000    0.700000
# 50%     45.000000         1.000000  ...    3.100000    0.930000
# 75%     58.000000         2.600000  ...    3.800000    1.100000
# max     90.000000        75.000000  ...    5.500000    2.800000
#
# [8 rows x 9 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
# age                 583 non-null int64
# gender              583 non-null object
# total Bilirubin     583 non-null float64
# direct Bilirubin    583 non-null float64
# total proteins      583 non-null int64
# albumin             583 non-null int64
# A/G ratio           583 non-null int64
# SGPT                583 non-null float64
# SGOT                583 non-null float64
# Alkphos             579 non-null float64
# y                   583 non-null object
# dtypes: float64(5), int64(4), object(2)
# memory usage: 50.2+ KB

# %%
import seaborn as sb

# %%
sb.pairplot(raw_data)

# %%
raw_data.y
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#       ...
# 578     no
# 579    yes
# 580    yes
# 581    yes
# 582     no
# Name: y, Length: 583, dtype: object

# %%
len(raw_data[raw_data['y']=='yes']),len(raw_data[raw_data['y']=='no'])
# Out:
# (416, 167)

# %%
sb.countplot(raw_data.y)

# %%
cols=raw_data.columns
cols
# Out:
# Index(['age', 'gender', 'total Bilirubin', 'direct Bilirubin',
#        'total proteins', 'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos',
#        'y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
for i in cols:
  sb.countplot(raw_data[i])
  plt.show()

# %%
import sklearn

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
raw_data.columns
# Out:
# Index(['age', 'gender', 'total Bilirubin', 'direct Bilirubin',
#        'total proteins', 'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos',
#        'y'],
#       dtype='object')

# %%
raw_data = pd.concat([raw_data,pd.get_dummies(raw_data['gender'])],axis=1)

# %%
raw_data.columns
# Out:
# Index(['age', 'gender', 'total Bilirubin', 'direct Bilirubin',
#        'total proteins', 'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos',
#        'y', 'Female', 'Male'],
#       dtype='object')

# %%
raw_data.drop('gender',axis=1,inplace=True)

# %%
raw_data.columns
# Out:
# Index(['age', 'total Bilirubin', 'direct Bilirubin', 'total proteins',
#        'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos', 'y', 'Female',
#        'Male'],
#       dtype='object')

# %%
raw_data.head()
# Out:
#    age  total Bilirubin  direct Bilirubin  ...    y  Female  Male
# 0   65              0.7               0.1  ...  yes       1     0
# 1   62             10.9               5.5  ...  yes       0     1
# 2   62              7.3               4.1  ...  yes       0     1
# 3   58              1.0               0.4  ...  yes       0     1
# 4   72              3.9               2.0  ...  yes       0     1
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
raw_data['y']=le.fit_transform(raw_data['y'])

# %%
raw_data.head(10)
# Out:
#    age  total Bilirubin  direct Bilirubin  ...  y  Female  Male
# 0   65              0.7               0.1  ...  1       1     0
# 1   62             10.9               5.5  ...  1       0     1
# 2   62              7.3               4.1  ...  1       0     1
# 3   58              1.0               0.4  ...  1       0     1
# 4   72              3.9               2.0  ...  1       0     1
# 5   46              1.8               0.7  ...  1       0     1
# 6   26              0.9               0.2  ...  1       1     0
# 7   29              0.9               0.3  ...  1       1     0
# 8   17              0.9               0.3  ...  0       0     1
# 9   55              0.7               0.2  ...  1       0     1
#
# [10 rows x 12 columns]

# %%
raw_data.isna().sum()
# Out:
# age                 0
# total Bilirubin     0
# direct Bilirubin    0
# total proteins      0
# albumin             0
# A/G ratio           0
# SGPT                0
# SGOT                0
# Alkphos             4
# y                   0
# Female              0
# Male                0
# dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 12 columns):
# age                 583 non-null int64
# total Bilirubin     583 non-null float64
# direct Bilirubin    583 non-null float64
# total proteins      583 non-null int64
# albumin             583 non-null int64
# A/G ratio           583 non-null int64
# SGPT                583 non-null float64
# SGOT                583 non-null float64
# Alkphos             579 non-null float64
# y                   583 non-null int64
# Female              583 non-null uint8
# Male                583 non-null uint8
# dtypes: float64(5), int64(5), uint8(2)
# memory usage: 46.8 KB

# %%
df=raw_data
df.fillna(df.mean(),inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 12 columns):
# age                 583 non-null int64
# total Bilirubin     583 non-null float64
# direct Bilirubin    583 non-null float64
# total proteins      583 non-null int64
# albumin             583 non-null int64
# A/G ratio           583 non-null int64
# SGPT                583 non-null float64
# SGOT                583 non-null float64
# Alkphos             583 non-null float64
# y                   583 non-null int64
# Female              583 non-null uint8
# Male                583 non-null uint8
# dtypes: float64(5), int64(5), uint8(2)
# memory usage: 46.8 KB

# %%
raw_data.columns
# Out:
# Index(['age', 'total Bilirubin', 'direct Bilirubin', 'total proteins',
#        'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos', 'y', 'Female',
#        'Male'],
#       dtype='object')

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mas=MaxAbsScaler()
data=pd.DataFrame(mas.fit_transform(raw_data.drop(['y','Female','Male'],axis=1)),columns=['age', 'total Bilirubin', 'direct Bilirubin', 'total proteins',
       'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos'])

# %%
data.head()
# Out:
#         age  total Bilirubin  direct Bilirubin  ...      SGPT      SGOT   Alkphos
# 0  0.722222         0.009333          0.005076  ...  0.708333  0.600000  0.321429
# 1  0.688889         0.145333          0.279188  ...  0.781250  0.581818  0.264286
# 2  0.688889         0.097333          0.208122  ...  0.729167  0.600000  0.317857
# 3  0.644444         0.013333          0.020305  ...  0.708333  0.618182  0.357143
# 4  0.800000         0.052000          0.101523  ...  0.760417  0.436364  0.142857
#
# [5 rows x 9 columns]

# %%
sb.pairplot(data)

# %%
for i in data.columns:
  sb.countplot(raw_data[i])
  plt.show()

# %%
data[['Female','Male','y']]=raw_data[['Female','Male','y']]

# %%
data.head()
# Out:
#         age  total Bilirubin  direct Bilirubin  ...  Female  Male  y
# 0  0.722222         0.009333          0.005076  ...       1     0  1
# 1  0.688889         0.145333          0.279188  ...       0     1  1
# 2  0.688889         0.097333          0.208122  ...       0     1  1
# 3  0.644444         0.013333          0.020305  ...       0     1  1
# 4  0.800000         0.052000          0.101523  ...       0     1  1
#
# [5 rows x 12 columns]

# %%
len(data[data['y']==0]),len(data[data['y']==1])
# Out:
# (167, 416)

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=0)
X_resampled,y_resampled=ros.fit_resample(data.drop(['y'],axis=1),data['y'])

print(len(data[data['y']==0]),len(data[data['y']==1]))
# Out:
# 167 416
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# ...

# %%
data.columns
# Out:
# Index(['age', 'total Bilirubin', 'direct Bilirubin', 'total proteins',
#        'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos', 'Female', 'Male',
#        'y'],
#       dtype='object')

# %%
new_data=pd.DataFrame(X_resampled,columns=['age', 'total Bilirubin', 'direct Bilirubin', 'total proteins',
       'albumin', 'A/G ratio', 'SGPT', 'SGOT', 'Alkphos', 'Female', 'Male'])
new_data['y']=y_resampled

# %%
sb.pairplot(new_data)

# %%
new_data.describe()
# Out:
#               age  total Bilirubin  ...        Male           y
# count  832.000000       832.000000  ...  832.000000  832.000000
# mean     0.483881         0.035314  ...    0.739183    0.500000
# std      0.183212         0.070909  ...    0.439345    0.500301
# min      0.044444         0.005333  ...    0.000000    0.000000
# 25%      0.344444         0.009333  ...    0.000000    0.000000
# 50%      0.483333         0.012000  ...    1.000000    0.500000
# 75%      0.633333         0.025333  ...    1.000000    1.000000
# max      1.000000         1.000000  ...    1.000000    1.000000
#
# [8 rows x 12 columns]

# %%
new_data.corr()
# Out:
#                        age  total Bilirubin  ...      Male         y
# age               1.000000         0.030916  ...  0.032756  0.158052
# total Bilirubin   0.030916         1.000000  ...  0.089892  0.285207
# direct Bilirubin  0.030961         0.880521  ...  0.100853  0.316763
# total proteins    0.069006         0.234269  ...  0.002250  0.210095
# albumin          -0.060952         0.236063  ...  0.084313  0.212459
# A/G ratio        -0.005847         0.257000  ...  0.081914  0.198707
# SGPT             -0.201132        -0.017046  ... -0.055897 -0.031710
# SGOT             -0.274194        -0.212196  ... -0.062445 -0.178145
# Alkphos          -0.215847        -0.204722  ... -0.005641 -0.188251
# Female           -0.032756        -0.089892  ... -1.000000 -0.090333
# Male              0.032756         0.089892  ...  1.000000  0.090333
# y                 0.158052         0.285207  ...  0.090333  1.000000
#
# [12 rows x 12 columns]

# %%
# sb.heatmap(df.corr(),annot=True,size)


fig, ax = plt.subplots(figsize=(20,20))         # Sample figsize in inches
sb.heatmap(new_data.corr(), annot=True, linewidths=.5, ax=ax)

# %%
new_data.to_csv('preprocessed.csv')

# %%
X = new_data[['total proteins','total Bilirubin','direct Bilirubin','albumin','A/G ratio','SGPT','SGOT','Alkphos']]
Y = new_data.y
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0)

# %%
# train a logistic regression model on the training set
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
logreg.score(X_test,Y_test)
# Out:
# 0.7211538461538461

# %%
from sklearn. ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=20)
rf.fit(X_train,Y_train)
rf.score(X_test,Y_test)
# Out:
# 0.8365384615384616

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
# make class predictions for the testing set
Y_pred_nb = nb.predict(X_test)
# calculate accuracy for logistic regression
from sklearn import metrics
print(metrics.accuracy_score(Y_test, Y_pred_nb))
nb.score(X_test,Y_test)
# Out:
# 0.6971153846153846
# 0.6971153846153846
